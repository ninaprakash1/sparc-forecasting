# %%
import numpy as np
import pandas as pd

from wwo_hist import retrieve_hist_data

# %%
frequency = 1

start_date = '01-JAN-2020'
end_date = '19-JAN-2022'
api_key = '8d0e4b3d61f149e095124908222101'
location_list = ['california']


hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for california
#
#
# Currently retrieving data for california: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.238659
# Currently retrieving data for california: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.422124
# Currently retrieving data for california: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.592465
# Currently retrieving data for california: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.748629
# Currently retrieving data for california: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.965990
# Currently retrieving data for california: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.199552
# Currently retrieving data for california: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.332978
# Currently retrieving data for california: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.492967
# Currently retrieving data for california: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.753523
# Currently retrieving data for california: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.021529
# Currently retrieving data for california: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:13.172363
# Currently retrieving data for california: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:14.475903
# Currently retrieving data for california: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:15.749474
# Currently retrieving data for california: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:16.994086
# Currently retrieving data for california: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:18.264577
# Currently retrieving data for california: from 2021-04-01 to 2021-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:19.499937
# Currently retrieving data for california: from 2021-05-01 to 2021-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:20.939031
# Currently retrieving data for california: from 2021-06-01 to 2021-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:22.142259
# Currently retrieving data for california: from 2021-07-01 to 2021-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:23.454434
# Currently retrieving data for california: from 2021-08-01 to 2021-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:24.626191
# Currently retrieving data for california: from 2021-09-01 to 2021-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:25.839100
# Currently retrieving data for california: from 2021-10-01 to 2021-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.156691
# Currently retrieving data for california: from 2021-11-01 to 2021-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:28.332145
# Currently retrieving data for california: from 2021-12-01 to 2021-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:29.506605
# Currently retrieving data for california: from 2022-01-01 to 2022-01-19
# Time elapsed (hh:mm:ss.ms) 0:00:30.403095
#
#
# export california completed!

# %%
df = pd.read_csv('california.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          9240 non-null   object
#  1   maxtempC           9240 non-null   int64
#  2   mintempC           9240 non-null   int64
#  3   totalSnow_cm       9240 non-null   float64
#  4   sunHour            9240 non-null   float64
#  5   uvIndex            9240 non-null   int64
#  6   moon_illumination  9240 non-null   int64
#  7   moonrise           9240 non-null   object
#  8   moonset            9240 non-null   object
#  9   sunrise            9240 non-null   object
#  10  sunset             9240 non-null   object
#  11  DewPointC          9240 non-null   int64
#  12  FeelsLikeC         9240 non-null   int64
#  13  HeatIndexC         9240 non-null   int64
#  14  WindChillC         9240 non-null   int64
#  15  WindGustKmph       9240 non-null   int64
#  16  cloudcover         9240 non-null   int64
#  17  humidity           9240 non-null   int64
#  18  precipMM           9240 non-null   float64
#  19  pressure           9240 non-null   int64
#  20  tempC              9240 non-null   int64
#  21  visibility         9240 non-null   int64
#  22  winddirDegree      9240 non-null   int64
#  23  windspeedKmph      9240 non-null   int64
#  24  location           9240 non-null   object
# dtypes: float64(3), int64(16), object(6)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2020-01-01 00:00:00        12         4           0.0      8.7        3
# 1  2020-01-01 01:00:00        12         4           0.0      8.7        3
# 2  2020-01-01 02:00:00        12         4           0.0      8.7        3
# 3  2020-01-01 03:00:00        12         4           0.0      8.7        3
# 4  2020-01-01 04:00:00        12         4           0.0      8.7        3
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 39  11:20 AM  11:08 PM  07:00 AM  ...            4
# 1                 39  11:20 AM  11:08 PM  07:00 AM  ...            4
# 2                 39  11:20 AM  11:08 PM  07:00 AM  ...            4
# 3                 39  11:20 AM  11:08 PM  07:00 AM  ...            4
# 4                 39  11:20 AM  11:08 PM  07:00 AM  ...            6
#
#    cloudcover  humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# 0           7        59       0.0      1020      6          10            302
# 1           8        59       0.0      1019      6          10            284
# 2           9        59       0.0      1019      5          10            267
# 3          10        59       0.0      1019      5          10            249
# 4          11        58       0.0      1019      5          10            239
#
#    windspeedKmph    location
# 0              2  california
# 1              2  california
# 2              2  california
# 3              2  california
# 4              3  california
#
# [5 rows x 25 columns]
